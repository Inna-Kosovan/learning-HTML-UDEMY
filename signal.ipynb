# %%
# %%writefile /content/drive/MyDrive/BINANCE/sygnal.py
# Out:
# Writing /content/drive/MyDrive/BINANCE/sygnal.py

# %%
# !pip install pyproject.toml

# %%
# !apt-get update
# !apt-get install libta-lib-dev

# %%
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# !tar -xzvf ta-lib-0.4.0-src.tar.gz
# Out:
# --2023-10-18 13:40:15--  http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz
# Resolving prdownloads.sourceforge.net (prdownloads.sourceforge.net)... 204.68.111.105
# Connecting to prdownloads.sourceforge.net (prdownloads.sourceforge.net)|204.68.111.105|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# --2023-10-18 13:40:15--  http://downloads.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz
# Resolving downloads.sourceforge.net (downloads.sourceforge.net)... 204.68.111.105
# Reusing existing connection to prdownloads.sourceforge.net:80.
# HTTP request sent, awaiting response... 302 Found
# Location: http://newcontinuum.dl.sourceforge.net/project/ta-lib/ta-lib/0.4.0/ta-lib-0.4.0-src.tar.gz [following]
# ...

# %%
# %cd ta-lib
# !./configure --prefix=/usr
# !make
# !make install
# Out:
# /content/ta-lib
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking for C compiler default output file name... a.out
# checking whether the C compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for a sed that does not truncate output... /usr/bin/sed
# ...

# %%
# !pip install TA-Lib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 357.1/357.1 kB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for TA-Lib: filename=TA_Lib-0.4.28-cp310-cp310-linux_x86_64.whl size=2017492 sha256=c4f9e2d8cd4628f6b92709e3dbe576bd07440d8ca384f71966e90066f0a74c68
#   Stored in directory: /root/.cache/pip/wheels/66/54/9d/10bfd00931c0c993f373269d350635df520b5064e5290a9d94
# Successfully built TA-Lib
# ...

# %%
# !pip install pandas scikit-learn tensorflow

# %%
# !pip install matplotlib

# %%
# !pip install ta
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for ta: filename=ta-0.10.2-py3-none-any.whl size=29089 sha256=9b973a454b27b7dbfdc611e97f1bfbe7a94785ea97db134567d3a85fd411a590
#   Stored in directory: /root/.cache/pip/wheels/47/51/06/380dc516ea78621870b93ff65527c251afdfdc5fa9d7f4d248
# Successfully built ta
# ...

# %%
# !pip list
# Out:
# Package                          Version
# -------------------------------- ---------------------
# absl-py                          1.4.0
# aiohttp                          3.8.6
# aiosignal                        1.3.1
# alabaster                        0.7.13
# albumentations                   1.3.1
# altair                           4.2.2
# anyio                            3.7.1
# appdirs                          1.4.4
# argon2-cffi                      23.1.0
# argon2-cffi-bindings             21.2.0
# array-record                     0.4.1
# arviz                            0.15.1
# astropy                          5.3.4
# astunparse                       1.6.3
# async-timeout                    4.0.3
# attrs                            23.1.0
# audioread                        3.0.1
# autograd                         1.6.2
# Babel                            2.13.0
# backcall                         0.2.0
# beautifulsoup4                   4.11.2
# ...

# %%
import os
import logging
from google.colab import drive  # <-- Add this import

# Configure logging
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[
                        logging.StreamHandler()
                    ])
logger = logging.getLogger(__name__)

# Mount Google Drive if not already mounted
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')
else:
    logger.info("Drive is already mounted.")
# Out:
# Mounted at /content/drive

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

def load_and_preprocess_data(file_path):
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print(f"File {file_path} not found.")
        return None

df = load_and_preprocess_data('/content/drive/MyDrive/BINANCE/processed_data.csv')

def test_load_and_preprocess_data():
    file_path = '/content/drive/MyDrive/BINANCE/processed_data.csv'
    df = load_and_preprocess_data(file_path)
    assert df is not None, f"Failed to load data from {file_path}"
    # Add more assertions as needed, e.g., on the shape or contents of df

test_load_and_preprocess_data()

df = load_and_preprocess_data('/content/drive/MyDrive/BINANCE/processed_data.csv')
print(df.head())  # Print the first few rows of the DataFrame

import matplotlib.pyplot as plt

df = load_and_preprocess_data('/content/drive/MyDrive/BINANCE/processed_data.csv')
df.hist()
plt.show()

import pdb

def load_and_preprocess_data(file_path):
    try:
        df = pd.read_csv(file_path)
        pdb.set_trace()  # Insert a breakpoint
        return df
    except FileNotFoundError:
        print(f"File {file_path} not found.")
        return None
# Out:
# Mounted at /content/drive
#     SYMBOL    TRADE_ID     PRICE  QUANTITY  BUYER_ORDER_ID  SELLER_ORDER_ID  \
# 0  BTCUSDT  3235808193  0.382538  0.000266     22695317626      22695318752
# 1  BTCUSDT  3235808194  0.382553  0.000055     22695318754      22695317119
# 2  BTCUSDT  3235808198  0.382553  0.000027     22695318815      22695317119
# 3  BTCUSDT  3235808196  0.382553  0.000140     22695318760      22695317119
# 4  BTCUSDT  3235808197  0.382553  0.000055     22695318786      22695317119
#
#    IS_BUYER_MARKET_MAKER  TRADE_HOUR
# 0                      1          11
# 1                      0          11
# 2                      0          11
# 3                      0          11
# 4                      0          11

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls /content/drive/MyDrive/

# %%
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

if ram_gb < 20:
  print('Not using a high-RAM runtime')
else:
  print('You are using a high-RAM runtime!')
# Out:
# Your runtime has 54.8 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
import os
import pandas as pd
import logging
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import LocalOutlierFactor
import matplotlib.pyplot as plt
import ta
import pdb

from google.colab import drive
drive.mount('/content/drive')

def load_and_preprocess_data(file_path):
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print(f"File {file_path} not found.")
        return None
df = load_and_preprocess_data('/content/drive/MyDrive/BINANCE/processed_data.csv')

def test_load_and_preprocess_data():
    file_path = '/content/drive/MyDrive/BINANCE/processed_data.csv'
    df = load_and_preprocess_data(file_path)
    assert df is not None, f"Failed to load data from {file_path}"
    # Add more assertions as needed, e.g., on the shape or contents of df

test_load_and_preprocess_data()

df = load_and_preprocess_data('/content/drive/MyDrive/BINANCE/processed_data.csv')
print(df.head())  # Print the first few rows of the DataFrame

import matplotlib.pyplot as plt

df = load_and_preprocess_data('/content/drive/MyDrive/BINANCE/processed_data.csv')
df.hist()
plt.show()

def load_and_preprocess_data(file_path):
    try:
        df = pd.read_csv(file_path)
        pdb.set_trace()  # Insert a breakpoint
        return df
    except FileNotFoundError:
        print(f"File {file_path} not found.")
        return None



# Configure logging
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[
                        logging.FileHandler("error.log"),
                        logging.StreamHandler()
                    ])
logger = logging.getLogger(__name__)

def read_csv_from_drive(file_path):
    """Function to read CSV from Google Drive."""
    try:
        return pd.read_csv(file_path)
    except Exception as e:
        logger.error(f"Error reading the file {file_path}. Exception: {e}")
        return None

def get_signals(df):
    """Function to detect anomalies, compute technical indicators, and add them to the dataframe."""
    if 'PRICE' not in df.columns or 'QUANTITY' not in df.columns:
        logger.error("PRICE or QUANTITY column is missing in the dataframe.")
        return

    feature_cols = ['PRICE', 'QUANTITY']

    # Normalize the data
    try:
        scaler = StandardScaler()
        data_normalized = scaler.fit_transform(df[feature_cols])
    except Exception as e:
        logger.error(f"Error normalizing data. Exception: {e}")
        return

    # Anomaly Detection using DBSCAN
    try:
        dbscan = DBSCAN(eps=0.5, min_samples=5).fit(data_normalized)
        df['DBSCAN_Anomaly'] = dbscan.labels_
        anomalies_dbscan = df[df['DBSCAN_Anomaly'] == -1]
        print(f'Anomalies detected using DBSCAN: {len(anomalies_dbscan)}')
        print(anomalies_dbscan.head())
    except Exception as e:
        logger.error(f"Error detecting anomalies using DBSCAN. Exception: {e}")

    # Anomaly Detection using LOF
    try:
        lof = LocalOutlierFactor(n_neighbors=20, contamination=0.01)
        df['LOF_Anomaly'] = lof.fit_predict(data_normalized)
        anomalies_lof = df[df['LOF_Anomaly'] == -1]
        print(f'Anomalies detected using LOF: {len(anomalies_lof)}')
        print(anomalies_lof.head())
    except Exception as e:
        logger.error(f"Error detecting anomalies using LOF. Exception: {e}")

    # Technical Indicators using `ta` library
    try:
        df['SMA10'] = df['PRICE'].rolling(window=10).mean()
        df['SMA30'] = df['PRICE'].rolling(window=30).mean()
        df['RSI'] = ta.momentum.RSIIndicator(df['PRICE']).rsi()
        macd = ta.trend.MACD(df['PRICE'])
        df['MACD'] = macd.macd()
        df['MACD_Signal'] = macd.macd_signal()

        print(df[['RSI', 'MACD', 'MACD_Signal']].head())
    except Exception as e:
        logger.error(f"Error computing technical indicators. Exception: {e}")

    # Save to CSV
    try:
        path = "/content/drive/MyDrive/BINANCE/Technical_indicators_simplified.csv"
        df.to_csv(path)
        logger.info(f"Data saved successfully to {path}")
    except Exception as e:
        logger.error(f"Error saving data to {path}. Exception: {e}")

# Assuming Google Drive is already mounted
df = read_csv_from_drive('/content/drive/MyDrive/BINANCE/processed_data.csv')

# Check if the dataframe is not empty before proceeding
if df is not None and not df.empty:
    get_signals(df)
else:
    logger.error("DataFrame is empty or None.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     SYMBOL    TRADE_ID     PRICE  QUANTITY  BUYER_ORDER_ID  SELLER_ORDER_ID  \
# 0  BTCUSDT  3235808193  0.382538  0.000266     22695317626      22695318752
# 1  BTCUSDT  3235808194  0.382553  0.000055     22695318754      22695317119
# 2  BTCUSDT  3235808198  0.382553  0.000027     22695318815      22695317119
# 3  BTCUSDT  3235808196  0.382553  0.000140     22695318760      22695317119
# 4  BTCUSDT  3235808197  0.382553  0.000055     22695318786      22695317119
#
#    IS_BUYER_MARKET_MAKER  TRADE_HOUR
# 0                      1          11
# 1                      0          11
# 2                      0          11
# 3                      0          11
# 4                      0          11

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')

def load_and_preprocess_data(file_path):
    try:
        df = pd.read_csv(file_path)
        return df
    except FileNotFoundError:
        print(f"File {file_path} not found.")
        return None

df = load_and_preprocess_data('/content/drive/MyDrive/BINANCE/processed_data.csv')

def test_load_and_preprocess_data():
    file_path = '/content/drive/MyDrive/BINANCE/processed_data.csv'
    df = load_and_preprocess_data(file_path)
    assert df is not None, f"Failed to load data from {file_path}"
    # Add more assertions as needed, e.g., on the shape or contents of df

test_load_and_preprocess_data()

df = load_and_preprocess_data('/content/drive/MyDrive/BINANCE/processed_data.csv')
print(df.head())  # Print the first few rows of the DataFrame

import matplotlib.pyplot as plt

df = load_and_preprocess_data('/content/drive/MyDrive/BINANCE/processed_data.csv')
df.hist()
plt.show()

import pdb

def load_and_preprocess_data(file_path):
    try:
        df = pd.read_csv(file_path)
        pdb.set_trace()  # Insert a breakpoint
        return df
    except FileNotFoundError:
        print(f"File {file_path} not found.")
        return None
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#     SYMBOL    TRADE_ID     PRICE  QUANTITY  BUYER_ORDER_ID  SELLER_ORDER_ID  \
# 0  BTCUSDT  3235808193  0.382538  0.000266     22695317626      22695318752
# 1  BTCUSDT  3235808194  0.382553  0.000055     22695318754      22695317119
# 2  BTCUSDT  3235808198  0.382553  0.000027     22695318815      22695317119
# 3  BTCUSDT  3235808196  0.382553  0.000140     22695318760      22695317119
# 4  BTCUSDT  3235808197  0.382553  0.000055     22695318786      22695317119
#
#    IS_BUYER_MARKET_MAKER  TRADE_HOUR
# 0                      1          11
# 1                      0          11
# 2                      0          11
# 3                      0          11
# 4                      0          11

# %%
def get_signals(df):
    """Function to detect anomalies, compute technical indicators, and add them to the dataframe."""

    # Check for PRICE and QUANTITY columns in the dataframe
    if 'PRICE' not in df.columns or 'QUANTITY' not in df.columns:
        logger.error("PRICE or QUANTITY column is missing in the dataframe.")
        return

    feature_cols = ['PRICE', 'QUANTITY']

    # Normalize the data
    try:
        scaler = StandardScaler()
        data_normalized = scaler.fit_transform(df[feature_cols])
    except Exception as e:
        logger.error(f"Error normalizing data. Exception: {e}")
        return

    # Anomaly Detection using DBSCAN
    try:
        dbscan = DBSCAN(eps=0.5, min_samples=5).fit(data_normalized)
        df['DBSCAN_Anomaly'] = dbscan.labels_
        anomalies_dbscan = df[df['DBSCAN_Anomaly'] == -1]
        print(f'Anomalies detected using DBSCAN: {len(anomalies_dbscan)}')
        print(anomalies_dbscan.head())
    except Exception as e:
        logger.error(f"Error detecting anomalies using DBSCAN. Exception: {e}")

    # Anomaly Detection using LOF
    try:
        lof = LocalOutlierFactor(n_neighbors=20, contamination=0.01)
        df['LOF_Anomaly'] = lof.fit_predict(data_normalized)
        anomalies_lof = df[df['LOF_Anomaly'] == -1]
        print(f'Anomalies detected using LOF: {len(anomalies_lof)}')
        print(anomalies_lof.head())
    except Exception as e:
        logger.error(f"Error detecting anomalies using LOF. Exception: {e}")

# %%
from google.colab import drive
import pandas as pd
import os
import logging
from sklearn import preprocessing
import matplotlib.pyplot as plt
import pickle

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Read the CSV file from Google Drive
df = read_csv_from_drive('/content/drive/MyDrive/BINANCE/processed_data.csv')


# Check if drive is already mounted, if not, mount it
if not os.path.exists('/content/drive/'):
    drive.mount('/content/drive/')

# Function to read CSV from Google Drive
def read_csv_from_drive(file_path):
      return pd.read_csv(file_path)

# Function to load and preprocess data
def load_and_preprocess_data(file_path):
    try:
        if file_path.endswith('.csv'):
            df = read_csv_from_drive(file_path)
        else:
            logger.error(f"Unsupported file format: {file_path}")
            return None
        return df
    except FileNotFoundError:
        logger.error(f"File {file_path} not found.")
        return None

# Print the first few rows of the DataFrame to ensure it's loaded correctly
    print(df.head())

# %%
from google.colab import drive
import pandas as pd
import os
import logging
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import LocalOutlierFactor
import matplotlib.pyplot as plt
import talib
from google.colab import drive
import pandas as pd
import os
import logging
from sklearn import preprocessing
import matplotlib.pyplot as plt
import pickle



# Configure logging
logging.basicConfig(level=logging.ERROR,
                    format='%(asctime)s - %(levelname)s - %(message)s',
                    handlers=[
                        logging.FileHandler("error.log"),
                        logging.StreamHandler()
                    ])
logger = logging.getLogger(__name__)

# Check if drive is already mounted, if not, mount it
if not os.path.exists('/content/drive/'):
    drive.mount('/content/drive/')
else:
    logger.info("Drive is already mounted.")

def read_csv_from_drive(file_path):
    """Function to read CSV from Google Drive."""
    try:
        return pd.read_csv(file_path)
    except Exception as e:
        logger.error(f"Error reading the file {file_path}. Exception: {e}")
        return None

def get_signals(df):
    """Function to detect anomalies and compute technical indicators."""

    # Check for PRICE and QUANTITY columns in the dataframe
    if 'PRICE' not in df.columns or 'QUANTITY' not in df.columns:
        logger.error("PRICE or QUANTITY column is missing in the dataframe.")
        return

    feature_cols = ['PRICE', 'QUANTITY']

    # Normalize the data
    try:
        scaler = StandardScaler()
        data_normalized = scaler.fit_transform(df[feature_cols])
    except Exception as e:
        logger.error(f"Error normalizing data. Exception: {e}")
        return

    # Anomaly Detection using DBSCAN
    try:
        dbscan = DBSCAN(eps=0.5, min_samples=5).fit(data_normalized)
        df['DBSCAN_Anomaly'] = dbscan.labels_
        anomalies_dbscan = df[df['DBSCAN_Anomaly'] == -1]
        print(f'Anomalies detected using DBSCAN: {len(anomalies_dbscan)}')
        print(anomalies_dbscan.head())
    except Exception as e:
        logger.error(f"Error detecting anomalies using DBSCAN. Exception: {e}")

    # Anomaly Detection using LOF
    try:
        lof = LocalOutlierFactor(n_neighbors=20, contamination=0.01)
        df['LOF_Anomaly'] = lof.fit_predict(data_normalized)
        anomalies_lof = df[df['LOF_Anomaly'] == -1]
        print(f'Anomalies detected using LOF: {len(anomalies_lof)}')
        print(anomalies_lof.head())
    except Exception as e:
        logger.error(f"Error detecting anomalies using LOF. Exception: {e}")

    # Technical Indicators (Simplified)
    try:
        df['SMA10'] = df['PRICE'].rolling(window=10).mean()
        df['SMA30'] = df['PRICE'].rolling(window=30).mean()
        print(df[['SMA10', 'SMA30']].head())
    except Exception as e:
        logger.error(f"Error computing technical indicators. Exception: {e}")

    # Save to CSV
    try:
        path = "/content/drive/MyDrive/BINANCE/Technical_indicators_simplified.csv"
        df.to_csv(path)
        logger.info(f"Data saved successfully to {path}")
    except Exception as e:
        logger.error(f"Error saving data to {path}. Exception: {e}")

# Read the CSV file from Google Drive
df = read_csv_from_drive('/content/drive/MyDrive/BINANCE/processed_data.csv')

# Check if the dataframe is not empty before proceeding
if df is not None:
    get_signals(df)
else:
    logger.error("DataFrame is empty or None.")

# %%
from google.colab import drive
import pandas as pd
import os
import logging
from sklearn import preprocessing
import matplotlib.pyplot as plt
import pickle

# Configure logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

# Check if drive is already mounted, if not, mount it
if not os.path.exists('/content/drive/'):
    drive.mount('/content/drive/')

# Function to read CSV from Google Drive
def read_csv_from_drive(file_path):
    return pd.read_csv(file_path)

# Function to load and preprocess data
def load_and_preprocess_data(file_path):
    try:
        if file_path.endswith('.csv'):
            df = read_csv_from_drive(file_path)
        else:
            logger.error(f"Unsupported file format: {file_path}")
            return None
        return df
    except FileNotFoundError:
        logger.error(f"File {file_path} not found.")
        return None

# Read the CSV file from Google Drive
df = read_csv_from_drive('/content/drive/MyDrive/BINANCE/processed_data.csv')

# Print the first few rows of the DataFrame to ensure it's loaded correctly
print(df.head())

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import LocalOutlierFactor

def get_signals(df):
    # Assuming df is your data and it has columns 'PRICE' and 'QUANTITY'
    feature_cols = ['PRICE', 'QUANTITY']

    # Normalize the data
    scaler = StandardScaler()
    data_normalized = scaler.fit_transform(df[feature_cols])

    # Anomaly Detection using DBSCAN
    dbscan = DBSCAN(eps=0.5, min_samples=5).fit(data_normalized)
    df['DBSCAN_Anomaly'] = dbscan.labels_
    anomalies_dbscan = df[df['DBSCAN_Anomaly'] == -1]
    print(f'Anomalies detected using DBSCAN: {len(anomalies_dbscan)}')
    print(anomalies_dbscan.head())

    # Anomaly Detection using LOF
    lof = LocalOutlierFactor(n_neighbors=20, contamination=0.01)
    df['LOF_Anomaly'] = lof.fit_predict(data_normalized)
    anomalies_lof = df[df['LOF_Anomaly'] == -1]
    print(f'Anomalies detected using LOF: {len(anomalies_lof)}')
    print(anomalies_lof.head())

    # Technical Indicators (Simplified)
    df['SMA10'] = df['PRICE'].rolling(window=10).mean()
    df['SMA30'] = df['PRICE'].rolling(window=30).mean()

    print(df[['SMA10', 'SMA30']].head())

    # Save to CSV
    path = "/content/drive/MyDrive/BINANCE/Technical_indicators_simplified.csv"
    df.to_csv(path)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN
from sklearn.neighbors import LocalOutlierFactor

def get_signals(df):
    # Assuming df is your data and it has columns 'PRICE' and 'QUANTITY'
    feature_cols = ['PRICE', 'QUANTITY']

    # Normalize the data
    scaler = StandardScaler()
    data_normalized = scaler.fit_transform(df[feature_cols])

    # Anomaly Detection using DBSCAN
    dbscan = DBSCAN(eps=0.5, min_samples=5).fit(data_normalized)
    df['DBSCAN_Anomaly'] = dbscan.labels_
    anomalies_dbscan = df[df['DBSCAN_Anomaly'] == -1]
    print(f'Anomalies detected using DBSCAN: {len(anomalies_dbscan)}')
    print(anomalies_dbscan.head())

    # Anomaly Detection using LOF
    lof = LocalOutlierFactor(n_neighbors=20, contamination=0.01)
    df['LOF_Anomaly'] = lof.fit_predict(data_normalized)
    anomalies_lof = df[df['LOF_Anomaly'] == -1]
    print(f'Anomalies detected using LOF: {len(anomalies_lof)}')
    print(anomalies_lof.head())

    # Technical Indicators (Simplified)
    df['SMA10'] = df['PRICE'].rolling(window=10).mean()
    df['SMA30'] = df['PRICE'].rolling(window=30).mean()

    print(df[['SMA10', 'SMA30']].head())

    # Save to CSV
    path = "/content/drive/MyDrive/BINANCE/Technical_indicators_simplified.csv"
    df.to_csv(path)

# %%
# Find the optimal number of clusters using the silhouette score
sil_scores = []
for n_clusters in range(2, 6):
    kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=42).fit(data_normalized)
    silhouette_avg = silhouette_score(data_normalized, kmeans.labels_)
    sil_scores.append((n_clusters, silhouette_avg))

optimal_clusters = max(sil_scores, key=lambda x: x[1])[0]
kmeans = KMeans(n_clusters=optimal_clusters, n_init=10, random_state=42).fit(data_normalized)

distances = np.linalg.norm(data_normalized - kmeans.cluster_centers_[kmeans.labels_], axis=1)
anomaly_threshold = np.percentile(distances, 95)
anomalies = df[distances > anomaly_threshold]

# Print anomalies detected with K-means
print(f'Optimal number of clusters: {optimal_clusters}')
print(f'Anomalies detected using K-means Clustering: {len(anomalies)}')
print(anomalies.head())



from sklearn.preprocessing import StandardScaler

def get_signals(df):

# Assuming df is your data and it has columns 'PRICE' and 'QUANTITY'
feature_cols = ['PRICE', 'QUANTITY']

# Normalize the data
scaler = StandardScaler()
data_normalized = scaler.fit_transform(df[feature_cols])

# Find the optimal number of clusters using the silhouette score
sil_scores = []
for n_clusters in range(2, 6):
    kmeans = KMeans(n_clusters=n_clusters, n_init=10, random_state=42).fit(data_normalized)
    silhouette_avg = silhouette_score(data_normalized, kmeans.labels_)
    sil_scores.append((n_clusters, silhouette_avg))

optimal_clusters = max(sil_scores, key=lambda x: x[1])[0]
kmeans = KMeans(n_clusters=optimal_clusters, n_init=10, random_state=42).fit(data_normalized)

distances = np.linalg.norm(data_normalized - kmeans.cluster_centers_[kmeans.labels_], axis=1)
anomaly_threshold = np.percentile(distances, 95)
anomalies = df[distances > anomaly_threshold]

print(f'Optimal number of clusters: {optimal_clusters}')
print(f'Anomalies detected using K-means Clustering: {len(anomalies)}')
print(anomalies.head())

# Anomaly Detection using Isolation Forest
feature_cols = ['PRICE', 'QUANTITY']
X = df[feature_cols]
clf = IsolationForest(contamination=0.01, random_state=42).fit(X)
df['Anomaly'] = clf.predict(X)

anomalies = df[df['Anomaly'] == -1]
print(f'Anomalies detected using Isolation Forest: {len(anomalies)}')
print(anomalies.head())
logger.error(f'Anomalies detected using Isolation Forest: {len(anomalies)}')
logger.error(anomalies.head().to_string())

# Technical Indicators
df['SMA10'] = df['PRICE'].rolling(window=10).mean()
df['SMA30'] = df['PRICE'].rolling(window=30).mean()
df['RSI'] = talib.RSI(df['PRICE'])
df['MACD'], df['MACD_Signal'], _ = talib.MACD(df['price'])

print(df[['RSI', 'MACD', 'MACD_Signal']].head())
logger.error(df[['RSI', 'MACD', 'MACD_Signal']].head().to_string())


from google.colab import drive
drive.mount('/content/drive')

# Save to CSV
path = "/content/drive/MyDrive/BINANCE/Technical_indicators_simplified.csv"
df.to_csv(path)
